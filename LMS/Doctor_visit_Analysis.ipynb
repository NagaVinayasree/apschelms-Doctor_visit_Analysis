# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the Dataset

# %%
df=pd.read_csv("DoctorVisits.csv")
print(df.head(15))
# Out:
#     Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0            1       1  female  0.19    0.55        1        4       1
# 1            2       1  female  0.19    0.45        1        2       1
# 2            3       1    male  0.19    0.90        3        0       0
# 3            4       1    male  0.19    0.15        1        0       0
# 4            5       1    male  0.19    0.45        2        5       1
# 5            6       1  female  0.19    0.35        5        1       9
# 6            7       1  female  0.19    0.55        4        0       2
# 7            8       1  female  0.19    0.15        3        0       6
# 8            9       1  female  0.19    0.65        2        0       5
# 9           10       1    male  0.19    0.15        1        0       0
# 10          11       1    male  0.19    0.45        1        0       0
# 11          12       1    male  0.19    0.25        2        0       2
# ...

# %% [markdown]
# # Retrive specific columns based on requriments of colmns

# %%
df[['gender','illness']]
# Out:
#       gender  illness
# 0     female        1
# 1     female        1
# 2       male        3
# 3       male        1
# 4       male        2
# ...      ...      ...
# 5185  female        0
# 5186    male        0
# 5187  female        1
# 5188  female        0
# 5189    male        0
#
# [5190 rows x 2 columns]

# %% [markdown]
# # Display information about the table columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %% [markdown]
# # Find the total no.of people based on their count of illness

# %%
df["illness"].value_counts()
# Out:
# 1    1638
# 0    1554
# 2     946
# 3     542
# 4     274
# 5     236
# Name: illness, dtype: int64

# %% [markdown]
# # Find out totoal no.of male and female in data set

# %%
df['gender'].value_counts()
# Out:
# female    2702
# male      2488
# Name: gender, dtype: int64

# %% [markdown]
# # find out total no.of male and female  seperate based on their count of illness

# %%
 df.groupby(["gender", "illness"]).size()
# Out:
# gender  illness
# female  0          679
#         1          834
#         2          531
#         3          333
#         4          167
#         5          158
# male    0          875
#         1          804
#         2          415
#         3          209
#         4          107
#         5           78
# dtype: int64

# %% [markdown]
# # visualize and analyse the maximum,minimum and medium income

# %%
y=list(df.income)
plt.boxplot(y)
plt.show()

# %% [markdown]
# # findout no.of days reduced activity of male and female seperately due to illness

# %%
df.groupby(['gender','reduced']).mean()
# Out:
#                  Unnamed: 0    visits       age    income   illness    health
# gender reduced
# female 0        2524.038512  0.229322  0.465755  0.482735  1.462144  1.115098
#        1        1985.768421  0.400000  0.325684  0.542105  2.242105  1.610526
#        2        1622.618182  0.672727  0.391455  0.560182  2.236364  1.781818
#        3         997.311111  1.333333  0.403111  0.516000  2.733333  1.733333
#        4        1237.740741  0.851852  0.458889  0.466667  2.222222  2.074074
#        5        1169.055556  1.444444  0.401667  0.614444  2.222222  2.500000
#        6        1382.545455  1.363636  0.426364  0.622727  2.363636  1.363636
#        7        1034.846154  1.384615  0.436154  0.473462  2.653846  2.230769
#        8        1883.090909  1.090909  0.471818  0.404545  2.181818  4.000000
#        9        1349.000000  0.500000  0.570000  0.825000  3.000000  1.000000
#        10       1099.428571  2.142857  0.512857  0.421429  2.571429  2.000000
# ...

# %% [markdown]
# # visualize is there is any missing values in the dataset based on a heat map

# %%
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # find out the correlation between different varibles in the given dataset correlation between different varibles

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='PuBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Analyse how the nincome of a patient affects the no.of visits to the hospital

# %%
plt.figure(figsize=(10,10))
plt.scatter(x='income',y='visits',data=df)
plt.xlabel('income')
plt.ylabel('visits')
# Out:
# Text(0, 0.5, 'visits')

# %% [markdown]
# # count and visualize the no.of males & females affected by illness

# %%
sns.histplot(df.gender,bins=2)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Count'>

# %% [markdown]
# # VIsualize the percentage of people getting govt health insurance due to low income

# %%
label=['yes','no']
Y=df[df['freepoor']=='yes']
N=df[df['freepoor']=='no']
x=[Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people getting govt health insurance due to low income ")
plt.show()

# %% [markdown]
# ## Visualize the percentage of people getting govt health insurance due to old age

# %%
label=['yes','no']
Y=df[df['freerepat']=='yes']
N=df[df['freerepat']=='no']
x=[Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people getting govt health insurance due to old ae,disability or vereran status ")
plt.show()

# %% [markdown]
# ## Visualize the percentage of people having private health isurance

# %%
label=['yes','no']
Y=df[df['private']=='yes']
N=df[df['private']=='no']ss
x=[Y.shape[0],N.shape[0]]
plt.figure(figsize=(5,5))
plt.pie(x,labels=label)
plt.title("% of people having private health insurance ")
plt.show()

# %% [markdown]
# # Plot horizontal barchart to analyse the reduced days of activity due to illness based on Gender

# %%
db=df.groupby('gender')['reduced'].sum().to_frame().reset_index()
plt.barh(db['gender'],db['reduced'])
plt.title("Bar chart")
plt.xlabel("Reduced Activity")
plt.ylabel('Gender')
plt.show()

# %% [markdown]
# # Add age_category column

# %%
df['age_category'] = np.select([
    (df['age'] == 0.19),
    (df['age'] >=0.20) & (df['age'] <= 0.39),
    (df['age'] >=0.40) & (df['age'] <= 0.59),
    (df['age'] >= 0.60)
    ], ['Teen', 'Adult', 'Middle Adult', 'Senoir Adult'])

# %%
df.tail(15)
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 5175        5176       0  female  0.72    0.25        0        0       1
# 5176        5177       0  female  0.72    0.25        0        0       0
# 5177        5178       0    male  0.72    0.55        0        0       0
# 5178        5179       0    male  0.72    0.25        0        0       0
# 5179        5180       0  female  0.72    0.35        0        0       0
# 5180        5181       0    male  0.19    0.25        1        0       1
# 5181        5182       0    male  0.19    0.75        1        0       0
# 5182        5183       0  female  0.19    0.45        0        0       0
# 5183        5184       0    male  0.22    1.10        0        0       0
# 5184        5185       0    male  0.22    1.50        0        0       0
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# ...

# %% [markdown]
# # illness based on age_category

# %%
 df.groupby(["age_category",'illness']).size()
# Out:
# age_category  illness
# Adult         0          746
#               1          748
#               2          383
#               3          178
#               4           85
#               5           43
# Middle Adult  0          237
#               1          236
#               2          146
#               3           85
#               4           48
#               5           50
# Senoir Adult  0          335
#               1          384
#               2          288
#               3          205
#               4          114
#               5          127
# Teen          0          236
#               1          270
#               2          129
#               3           74
#               4           27
#               5           16
# dtype: int64

# %% [markdown]
# ### No.of people are ill based on Age Category

# %%
db=df.groupby('age_category')['illness'].sum().to_frame().reset_index()
plt.bar(db['age_category'],db['illness'])
plt.title("Bar chart")
plt.xlabel("Age Category")
plt.ylabel('illness')
plt.show()

# %% [markdown]
# # income based on age_category

# %%
db=df.groupby('age_category')['income'].sum().to_frame().reset_index()
plt.plot(db['age_category'],db['income'])
plt.xlabel("Age Category")
plt.ylabel('income')
plt.show()

# %% [markdown]
# # health based on Age_category

# %%
df.groupby('age_category')['health'].hist(legend=True)
# Out:
# age_category
# Adult           AxesSubplot(0.125,0.11;0.775x0.77)
# Middle Adult    AxesSubplot(0.125,0.11;0.775x0.77)
# Senoir Adult    AxesSubplot(0.125,0.11;0.775x0.77)
# Teen            AxesSubplot(0.125,0.11;0.775x0.77)
# Name: health, dtype: object
